# %%
import pandas as pd

# %%
df = pd.read_csv('amostras.csv')

# %%
display(df, index="Unnamed: 0")
# Out:
#     Unnamed: 0         Tempo  ADC0_tensao  ADC0_corrente  ADC1_tensao  \
# 0            0  1.702060e+12     0.009775       0.000054          NaN
# 1            1  1.702060e+12          NaN            NaN     0.004888
# 2            2  1.702060e+12     0.009775       0.000054          NaN
# 3            3  1.702060e+12          NaN            NaN     0.004888
# 4            4  1.702060e+12     0.009775       0.000054          NaN
# ..         ...           ...          ...            ...          ...
# 95          95  1.702060e+12          NaN            NaN     0.004888
# 96          96  1.702060e+12     0.009775       0.000054          NaN
# 97          97  1.702060e+12          NaN            NaN     0.004888
# 98          98  1.702060e+12     0.009775       0.000054          NaN
# 99          99  1.702060e+12          NaN            NaN     0.004888
#
#     ADC1_corrente
# 0             NaN
# 1        0.000005
# 2             NaN
# 3        0.000005
# 4             NaN
# ...
